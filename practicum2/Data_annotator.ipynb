# %% [markdown]
# # RO47002 Machine Learning for Robotics
# * (c) TU Delft, 2024
# * Period: 2024-2025, Q1
# * Course homepage: https://brightspace.tudelft.nl/d2l/home/682421

# %% [markdown]
# Make sure you fill in any place that says `YOUR CODE HERE` or `YOUR ANSWER HERE`. Moreover, if you see an empty cell, please DO NOT delete it, instead run that cell as you would run all other cells. Please fill in your name(s) and other required details below:

# %%
GROUP_NUMBER = "31"
STUDENT_NAME1 = "Marcel Riedeman"
STUDENT_NUMBER1 = "5314429"
STUDENT_NAME2 = "Harsh Bhatia"
STUDENT_NUMBER2 = "6315658"

# %%
# Note: this block is a check that you have filled in the above information.
# It will throw an AssertionError until all fields are filled
assert(GROUP_NUMBER != "")
assert(STUDENT_NAME1 != "")
assert(STUDENT_NUMBER1 != "")
assert(STUDENT_NAME2 != "")
assert(STUDENT_NUMBER2 != "")

# %% [markdown]
# ### General announcements
#
# * Do *not* share your solutions, and do *not* copy solutions from others. By submitting your solutions, you claim that you and your lab partner alone are responsible for this code.
#
# * Do *not* email questions directly, since we want to provide everybody with the same information and avoid repeating the same answers. Instead, please post your questions regarding this assignment in the correct support forum on Brightspace, this way everybody can benefit from the response. If you do have a particular question that you want to ask directly, please use the scheduled practicum hours to ask a TA.
#
# * There is a strict deadline for each assignment. Students are responsible to ensure that they have uploaded their work in time. So, please double check that your upload succeeded to the Brightspace and avoid any late penalties.
#
# * This [Jupyter notebook](https://jupyter.org/) uses `nbgrader` to help us with automated tests. `nbgrader` will make various cells in this notebook "uneditable" or "unremovable" and gives them a special id in the cell metadata. This way, when we run our checks, the system will check the existence of the cell ids and verify the number of points and which checks must be run. While there are ways that you can edit the metadata and work around the restrictions to delete or modify these special cells, you should not do that since then our nbgrader backend will not be able to parse your notebook and give you points for the assignment. You are free to add additional cells, but if you find a cell that you cannot modify or remove, please know that this is on purpose.
#
# * This notebook will have in various places a line that throws a `NotImplementedError` exception. These are locations where the assignment requires you to adapt the code! These lines are just there as a reminder for youthat you have not yet adapted that particular piece of code, especially when you execute all the cells. Once your solution code replaced these lines, it should accordingly *not* throw any exceptions anymore.
#
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).

# %% [markdown]
# ---

# %% [markdown]
# # RO4702 - Practicum week 2 - Annotator
#
# * Topic: Data collection
# * Year: 2024-2025
# * Book chapters: 2, 3

# %% [markdown]
# ### Installation
#
# Install the required dependency:
#
# ```bash
# pip install ipympl
# ```
#
# ### Usage
# - Left Click: Label the tip.
# - Right Click: Label the end.
# - Use the slider to switch images after labeling.
# - Save annotations periodically with the "Save" button (display(save_button)).

# %%
# Python ≥3.5 is required
import sys
assert sys.version_info >= (3, 5)

# Scikit-Learn ≥0.20 is required
import sklearn
assert sklearn.__version__ >= "0.20"

# Common imports
import numpy as np
import glob, os
import pickle
import skimage
import skimage.transform

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# %%
import ipywidgets as widgets
from ipywidgets import interact, interactive, IntSlider
from IPython.display import display

import matplotlib.patches as patches

# %% [markdown]
# Replace the path below with the path to your image folder

# %%
IMAGE_DIR = 'images/lab_partner1'

# %% [markdown]
# ## Get the Data

# %% [markdown]
# Read an image, and visualize it

# %% [markdown]
# ## Load all images

# %%
filenames = glob.glob(os.path.join(IMAGE_DIR, '*.JPG'))
filenames = sorted(filenames)
N = len(filenames)
print(f'found {N} images in target directory')
# Out:
# found 37 images in target directory

# %%
MAX_SIZE = 1024

def load_and_resize_image(filename, overwrite=False):
    print(f'loading "{filename}" ...')
    I = plt.imread(filename)
    
    # is the width or height too large?
    oversize_ratio = max(I.shape[0] / MAX_SIZE, I.shape[1] / MAX_SIZE)
    if oversize_ratio > 1.0:
        print('resizing image ...')
        I = skimage.transform.rescale(I, (1./oversize_ratio, 1/oversize_ratio, 1), anti_aliasing=True)
        
        # overwrite the old image file after resizing
        if overwrite:
            print(f'overwriting "{filename}" ...')
            plt.imsave(filename, I)
            
    return I

# %%
overwrite = True

Is = [load_and_resize_image(filename, overwrite) for filename in filenames]
print('loaded %d images' % len(Is))
# Out:
# loading "images/lab_partner1/IMG_8298.JPG" ...
# loading "images/lab_partner1/IMG_8299.JPG" ...
# loading "images/lab_partner1/IMG_8300.JPG" ...
# loading "images/lab_partner1/IMG_8301.JPG" ...
# loading "images/lab_partner1/IMG_8302.JPG" ...
# loading "images/lab_partner1/IMG_8303.JPG" ...
# loading "images/lab_partner1/IMG_8304.JPG" ...
# loading "images/lab_partner1/IMG_8305.JPG" ...
# loading "images/lab_partner1/IMG_8306.JPG" ...
# loading "images/lab_partner1/IMG_8307.JPG" ...
# loading "images/lab_partner1/IMG_8308.JPG" ...
# loading "images/lab_partner1/IMG_8309.JPG" ...
# loading "images/lab_partner1/IMG_8310.JPG" ...
# loading "images/lab_partner1/IMG_8311.JPG" ...
# loading "images/lab_partner1/IMG_8312.JPG" ...
# loading "images/lab_partner1/IMG_8313.JPG" ...
# loading "images/lab_partner1/IMG_8314.JPG" ...
# loading "images/lab_partner1/IMG_8315.JPG" ...
# loading "images/lab_partner1/IMG_8316.JPG" ...
# loading "images/lab_partner1/IMG_8317.JPG" ...
# loading "images/lab_partner1/IMG_8318.JPG" ...
# loading "images/lab_partner1/IMG_8319.JPG" ...
# loading "images/lab_partner1/IMG_8320.JPG" ...
# loading "images/lab_partner1/IMG_8321.JPG" ...
# loading "images/lab_partner1/IMG_8322.JPG" ...
# loading "images/lab_partner1/IMG_8323.JPG" ...
# loading "images/lab_partner1/IMG_8324.JPG" ...
# loading "images/lab_partner1/IMG_8325.JPG" ...
# loading "images/lab_partner1/IMG_8326.JPG" ...
# loading "images/lab_partner1/IMG_8327.JPG" ...
# loading "images/lab_partner1/IMG_8328.JPG" ...
# loading "images/lab_partner1/IMG_8329.JPG" ...
# loading "images/lab_partner1/IMG_8330.JPG" ...
# loading "images/lab_partner1/IMG_8335.JPG" ...
# loading "images/lab_partner1/IMG_8336.JPG" ...
# loading "images/lab_partner1/IMG_8346.JPG" ...
# loading "images/lab_partner1/IMG_8347.JPG" ...
# loaded 37 images

# %%
import pickle

annot_filename = os.path.join(IMAGE_DIR, 'annots.npy')
annot_exists = os.path.isfile(annot_filename)

print(f'Looking for annotations file "{annot_filename}":', 'found' if annot_exists else 'NOT found')

# load annotations
if annot_exists:
    print('Loading annotations')
    annots = pickle.load(open(annot_filename, 'rb'))
else:
    print('Initializing empty annotations array')
    annots = np.zeros((N,4)) # x1, y1, x2, y2
# Out:
# Looking for annotations file "images/lab_partner1/annots.npy": found
# Loading annotations

# %% [markdown]
# ### Annotate

# %% [markdown]
# We will use here `%matplotlib widget` to enable interactive widgets in this notebook. Interactive widgets can take up a lot of memory howeever, so in other notebooks we might prefer to use `%matplotlib inline` to just save plotted results as images without interaction.

# %%
# %matplotlib widget

# %%
# Initialize a figure and axis globally for continuous updates
fig, ax = plt.subplots()

# Initialize plot elements for updating
plt_points_tip = None
plt_points_end = None

# Variable to keep track of event connection
click_cid = None

def annotate_image(idx):
    global plt_points_tip, plt_points_end, click_cid

    # Clear the axis to prepare for a new image
    ax.clear()

    # Load the current image
    I = Is[idx]

    # Display the image
    ax.imshow(I)
    
    # Plot the current annotation points
    plt_points_tip, = ax.plot(annots[idx, 0], annots[idx, 1], 'gx', label='tip (left click)')
    plt_points_end, = ax.plot(annots[idx, 2], annots[idx, 3], 'rx', label='end (right click)')
    ax.legend()

    def onclick(event):
        # Check if the click occurred within the image axis
        if event.inaxes != ax:
            return  # Ignore clicks outside the image area
        
        cx, cy = event.xdata, event.ydata  # Get the click coordinates
        button = event.button  # 1 for left click, 3 for right click

        # Update annotation points based on the click
        if button == 1:
            plt_points_tip.set_xdata([cx])
            plt_points_tip.set_ydata([cy])
            annots[idx, 0] = cx  # Update only the relevant index
            annots[idx, 1] = cy
        elif button == 3:
            plt_points_end.set_xdata([cx])
            plt_points_end.set_ydata([cy])
            annots[idx, 2] = cx  # Update only the relevant index
            annots[idx, 3] = cy
        
        fig.canvas.draw_idle()  # Redraw the figure to reflect updates

        # Print the updated annotations for debugging
        print(f'Updated annotations for index {idx}: {annots[idx]}')

    # Disconnect previous event handlers to prevent duplicates
    if click_cid is not None:
        fig.canvas.mpl_disconnect(click_cid)

    # Connect the click event handler and keep track of the connection ID
    click_cid = fig.canvas.mpl_connect('button_press_event', onclick)

def on_save_button_clicked(b):
    print(f'Saving annotations "{annot_filename}"')
    pickle.dump(annots, open(annot_filename, 'wb'))

save_button = widgets.Button(description="Save changes!")
save_button.on_click(on_save_button_clicked)

interactive(annotate_image, idx=IntSlider(min=0, max=len(Is)-1, continuous_update=False))
# Out:
# interactive(children=(IntSlider(value=0, continuous_update=False, description='idx', max=36), Output()), _dom_…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
#
# Updated annotations for index 21: [636.17532468 532.27922078 555.61526608 140.10009766]
# Updated annotations for index 21: [397.21428571  73.05844156 555.61526608 140.10009766]
# Updated annotations for index 21: [397.21428571  73.05844156 627.86363636 530.2012987 ]
# Updated annotations for index 22: [401.37012987  77.21428571 345.74513621 142.17801973]
# Updated annotations for index 22: [401.37012987  77.21428571 625.78571429 526.04545455]
# Updated annotations for index 23: [397.21428571  91.75974026 281.3295518  304.94860364]
# Updated annotations for index 23: [397.21428571  91.75974026 625.78571429 555.13636364]
# Updated annotations for index 24: [397.21428571  95.91558442 372.75812322 432.39448052]
# Updated annotations for index 24: [397.21428571  95.91558442 611.24025974 586.30519481]
# Updated annotations for index 25: [451.24025974  54.35714286 414.31656478 596.55032468]
# Updated annotations for index 25: [451.24025974  54.35714286 569.68181818 600.85064935]
# Updated annotations for index 26: [442.92857143  62.66883117 615.87500634 600.70616883]
# Updated annotations for index 26: [442.92857143  62.66883117 544.74675325 598.77272727]
# Updated annotations for index 27: [445.00649351  75.13636364 819.51136998 494.73214286]
# Updated annotations for index 27: [445.00649351  75.13636364 559.29220779 607.08441558]
# Updated annotations for index 27: [445.00649351  75.13636364 536.43506494 594.61688312]
# Updated annotations for index 28: [307.86363636  97.99350649 634.57630504 307.71915584]
# Updated annotations for index 28: [307.86363636  97.99350649 426.30519481 611.24025974]
# Updated annotations for index 29: [289.16233766 102.14935065 759.25162972 153.95292208]
# Updated annotations for index 29: [289.16233766 102.14935065 409.68181818 600.85064935]
# Updated annotations for index 30: [216.43506494  97.99350649 472.49838296 120.70616883]
# Updated annotations for index 30: [216.43506494  97.99350649 399.29220779 590.46103896]
# Updated annotations for index 31: [235.13636364  97.99350649 285.48539595 195.51136364]
# Updated annotations for index 31: [235.13636364  97.99350649 395.13636364 575.91558442]
# Updated annotations for index 32: [216.43506494  87.6038961  260.55033102 444.86201299]
# Updated annotations for index 32: [411.75974026 571.75974026 260.55033102 444.86201299]
# Updated annotations for index 33: [ 21.11038961 291.24025974 335.35552582 627.02652572]
# Updated annotations for index 33: [ 21.11038961 291.24025974 455.3961039  422.14935065]
# Updated annotations for index 34: [ 19.03246753 295.3961039  568.08279855 637.41613611]
# Updated annotations for index 34: [ 19.03246753 295.3961039  457.47402597 415.91558442]
# Updated annotations for index 35: [154.0974026  619.55194805 811.19968167 485.03516259]
# Updated annotations for index 35: [154.0974026  619.55194805 580.07142857 366.04545455]
# Updated annotations for index 36: [176.95454545 617.47402597 792.49838296 335.42477298]
# Updated annotations for index 36: [176.95454545 617.47402597 594.61688312 349.42207792]
# Saving annotations "images/lab_partner1/annots.npy"
# Saving annotations "images/lab_partner1/annots.npy"

# %% [markdown]
# ### Save your annotations
# Run the cell below should give us a buttom "save changes". Click that buttom and save the annotations into 'annots.npy'

# %%
display(save_button)
# Out:
# Button(description='Save changes!', style=ButtonStyle())
